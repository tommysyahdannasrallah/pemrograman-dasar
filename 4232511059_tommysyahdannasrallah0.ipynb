# %% [markdown]
# <a href="https://colab.research.google.com/github/tommysyahdannasrallah/pemrograman-dasar/blob/main/4232511059_tommysyahdannasrallah0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# biodata saya

nama = "tommy syahdan nasrallah"
umur = 20
tempat_lahir = "batam"
agama = "islam"
jenis_kelamin = "laki-laki"
jurusan = "RPE"
semester = 3
matakuliah = 'pemerograman dasar'
dosen_pengampu = "muhammad veven"
status_lulus = False



print (nama)
print (umur)
print (tempat_lahir)
print (agama)
print (jenis_kelamin)
print (jurusan)
print (semester)
print (matakuliah)
print (dosen_pengampu)
print (status_lulus)
# Out:
# tommy syahdan nasrallah
# 20
# batam
# islam
# laki-laki
# RPE
# 3
# pemerograman dasar
# muhammad veven
# False
